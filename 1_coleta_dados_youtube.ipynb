# %% [markdown]
# <a href="https://colab.research.google.com/github/CaioHenrique28/ciencia-dados-santander/blob/main/1_coleta_dados_youtube.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Passo 1: Instala a ferramenta
# !pip install google-api-python-client --quiet
from googleapiclient.discovery import build

# Passo 2: Configura a Munição
# Exemplo de como tem que ficar: API_KEY = "AIzaSyD_8723hJksd..."
API_KEY = "AIzaSyBN5BCjifgaWymnbDOTrZpvuSlPcmP0O3U"

# Passo 3: O Teste de Conexão
try:
    youtube = build('youtube', 'v3', developerKey=API_KEY)

    # Busca 1 vídeo do Exército para ver se funciona
    request = youtube.search().list(
        part="snippet",
        q="Exército Brasileiro",
        maxResults=1,
        type="video"
    )
    response = request.execute()

    print("SUCESSO! CONEXÃO ESTABELECIDA.")
    print("Título do vídeo encontrado: " + response['items'][0]['snippet']['title'])

except Exception as e:
    print("ERRO: A chave ainda não está funcionando ou foi colada errada.")
    print(f"Detalhe do erro: {e}")
# Out:
# SUCESSO! CONEXÃO ESTABELECIDA.
# Título do vídeo encontrado: &#39;É muito boa&#39;, diz comandante do EXÉRCITO sobre relação com PRESIDENTE LULA
